# %%
import pandas as pd
import os,sys
sys.path.append(os.path.abspath(os.path.join('..','scripts')))
from preprocess import cleaning
from eda import analysis

# %%
bna=cleaning.load_data('BNA','2015-01-01','2025-01-31')
bna
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price       Date  Close  High   Low  Open  Volume
# 0     2015-01-02   7.70  7.70  7.70  7.70     400
# 1     2015-01-05   7.92  7.92  7.50  7.50     290
# 2     2015-01-06   7.92  7.92  7.92  7.92       0
# 3     2015-01-07   7.92  7.92  7.92  7.92       0
# 4     2015-01-08   7.57  7.65  7.57  7.60    2750
# ...          ...    ...   ...   ...   ...     ...
# 1786  2022-02-24   8.33  8.37  8.22  8.22    3746
# 1787  2022-02-25   8.30  8.30  8.29  8.29     544
# 1788  2022-02-28   8.24  8.29  8.02  8.29   24920
# 1789  2022-03-01   8.29  8.35  8.19  8.30    8820
# 1790  2022-03-02   8.29  8.29  8.29  8.29       0
#
# [1791 rows x 6 columns]

# %%
cleaning.stat(bna)
# Out:
# Price                           Date        Close         High          Low  \
# count                           1791  1791.000000  1791.000000  1791.000000
# mean   2018-07-26 06:50:03.015075328    10.812077    10.880056    10.696494
# min              2015-01-02 00:00:00     6.950000     7.000000     6.950000
# 25%              2016-10-11 12:00:00     8.565000     8.600000     8.480000
# 50%              2018-07-24 00:00:00     9.700000     9.800000     9.600000
# 75%              2020-05-06 12:00:00    12.295000    12.325000    12.125000
# max              2022-03-02 00:00:00    21.900000    22.000000    21.410000
# std                              NaN     2.998288     3.023733     2.962952
#
# Price         Open        Volume
# count  1791.000000  1.791000e+03
# mean     10.798626  1.455790e+04
# min       7.000000  0.000000e+00
# 25%       8.540000  1.120500e+03
# 50%       9.780000  5.051000e+03
# 75%      12.210000  1.374700e+04
# max      21.920000  1.501394e+06
# ...

# %%
cleaning.Inspect(bna)
# Out:
# {'data_types': Price
#  Date      datetime64[ns]
#  Close            float64
#  High             float64
#  Low              float64
#  Open             float64
#  Volume             int64
#  dtype: object,
#  'missing_values': Price
#  Date      0
#  Close     0
#  High      0
#  Low       0
#  Open      0
#  Volume    0
#  dtype: int64,
#  'duplicate_rows': 0}

# %%
cleaning.detect_outliers_with_boxplot(bna,'Close')

# %%
analysis.closing(bna,'BNA')

# %%
analysis.precentage_change(bna)
# Out:
# /Users/amantebeje/Desktop/projects/gmf-investments-portfolio-forecasting-/scripts/eda.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
analysis.rolling_avg(bna)

# %%
analysis.outliers(bna)
# Out:
# Days with Unusually High or Low Returns:
# Price           Close       High        Low       Open  Volume  Daily Change  \
# Date
# 2015-02-27   8.100000   8.100000   7.650000   7.650000   66721      6.020949
# 2015-03-02   8.590000   8.590000   8.400000   8.400000   72818      6.049380
# 2015-03-09   9.570000   9.600000   9.330000   9.330000   29850      5.629131
# 2015-03-17   9.790000   9.790000   9.000000   9.200000   18466      5.952383
# 2015-06-01  11.390000  11.460000  11.150000  11.460000   39117     23.939074
# 2015-07-21  14.700000  14.700000  14.350000  14.700000  161851     11.363637
# 2015-09-02  13.060000  13.400000  13.000000  13.400000   21885     -5.839939
# 2016-01-12  12.410000  12.410000  12.010000  12.050000   47266      6.068376
# 2016-01-13  13.160000  13.160000  12.700000  12.780000   38161      6.043513
# 2016-01-25  11.820000  11.820000  11.170000  11.170000    6004      6.008969
# ...

# %%
analysis.var_sharpe(bna)
# Out:
# Value at Risk (VaR) at 95.0% confidence level: -2.29%
# Sharpe Ratio: 0.01

# %%
analysis.decompose(bna)
