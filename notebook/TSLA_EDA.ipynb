# %%
import pandas as pd
import os,sys
sys.path.append(os.path.abspath(os.path.join('..','scripts')))
from preprocess import cleaning
from eda import analysis

# %%
tsla=cleaning.load_data('TSLA','2015-01-01','2025-01-31')
tsla
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price       Date       Close        High         Low        Open    Volume
# 0     2015-01-02   14.620667   14.883333   14.217333   14.858000  71466000
# 1     2015-01-05   14.006000   14.433333   13.810667   14.303333  80527500
# 2     2015-01-06   14.085333   14.280000   13.614000   14.004000  93928500
# 3     2015-01-07   14.063333   14.318667   13.985333   14.223333  44526000
# 4     2015-01-08   14.041333   14.253333   14.000667   14.187333  51637500
# ...          ...         ...         ...         ...         ...       ...
# 2530  2025-01-24  406.579987  418.880005  405.779999  414.450012  56427100
# 2531  2025-01-27  397.149994  406.690002  389.000000  394.799988  58125500
# 2532  2025-01-28  398.089996  400.589996  386.500000  396.910004  48910700
# 2533  2025-01-29  389.100006  398.589996  384.480011  395.209991  68033600
# ...

# %%
cleaning.stat(tsla)
# Out:
# Price                           Date        Close         High          Low  \
# count                           2535  2535.000000  2535.000000  2535.000000
# mean   2020-01-14 14:32:31.242603776   117.848209   120.474827   115.097514
# min              2015-01-02 00:00:00     9.578000    10.331333     9.403333
# 25%              2017-07-10 12:00:00    17.228000    17.527667    16.942000
# 50%              2020-01-15 00:00:00    30.298000    32.329334    29.760000
# 75%              2022-07-21 12:00:00   221.525002   226.696671   217.061661
# max              2025-01-30 00:00:00   479.859985   488.540009   457.510010
# std                              NaN   116.508288   119.236025   113.698930
#
# Price         Open        Volume
# count  2535.000000  2.535000e+03
# mean    117.877662  1.120308e+08
# min       9.488000  1.062000e+07
# 25%      17.259334  6.680295e+07
# 50%      31.299999  9.264180e+07
# 75%     222.653336  1.294283e+08
# max     475.899994  9.140820e+08
# ...

# %%
cleaning.Inspect(tsla)
# Out:
# {'data_types': Price
#  Date      datetime64[ns]
#  Close            float64
#  High             float64
#  Low              float64
#  Open             float64
#  Volume             int64
#  dtype: object,
#  'missing_values': Price
#  Date      0
#  Close     0
#  High      0
#  Low       0
#  Open      0
#  Volume    0
#  dtype: int64,
#  'duplicate_rows': 0}

# %%
cleaning.detect_outliers_with_boxplot(tsla,'Close')

# %%
analysis.closing(tsla,'TSLA')

# %%
analysis.precentage_change(tsla)
# Out:
# /Users/amantebeje/Desktop/projects/gmf-investments-portfolio-forecasting-/scripts/eda.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
analysis.rolling_avg(tsla)

# %%
analysis.outliers(tsla)
# Out:
# Days with Unusually High or Low Returns:
# Price            Close        High         Low        Open     Volume  \
# Date
# 2015-11-04   15.442000   15.516000   15.013333   15.133333  190896000
# 2018-08-02   23.302668   23.332666   21.544001   21.896000  348225000
# 2018-09-28   17.651333   18.533333   17.370667   18.017332  504745500
# 2018-10-01   20.713333   20.762667   20.070000   20.384666  326664000
# 2018-10-23   19.609333   19.862000   17.473333   17.591333  285417000
# 2019-01-18   20.150667   21.808666   19.982000   21.533333  362262000
# 2019-07-25   15.254667   15.633333   15.036667   15.566667  336274500
# 2019-10-24   19.978666   20.328667   19.280001   19.891333  445813500
# 2020-02-03   52.000000   52.409332   44.901333   44.912666  705975000
# 2020-02-04   59.137333   64.599335   55.591999   58.863998  914082000
# 2020-02-05   48.980000   56.398666   46.940666   54.883999  726357000
# 2020-02-27   45.266666   49.318001   44.599998   48.666668  364158000
# ...

# %%
analysis.var_sharpe(tsla)
# Out:
# Value at Risk (VaR) at 95.0% confidence level: -5.14%
# Sharpe Ratio: 0.05

# %%
analysis.decompose(tsla)
