# %%
import pandas as pd
import os,sys
sys.path.append(os.path.abspath(os.path.join('..','scripts')))
from preprocess import cleaning
from eda import analysis

# %%
spy=cleaning.load_data('SPY','2015-01-01','2025-01-31')
spy
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price       Date       Close        High         Low        Open     Volume
# 0     2015-01-02  172.592865  173.811099  171.542672  173.391022  121465900
# 1     2015-01-05  169.475937  171.702341  169.165084  171.534312  169632600
# 2     2015-01-06  167.879639  170.316081  167.073085  169.786780  209151400
# 3     2015-01-07  169.971603  170.316070  168.770189  169.223867  125346700
# 4     2015-01-08  172.987732  173.206180  171.383047  171.399841  147217800
# ...          ...         ...         ...         ...         ...        ...
# 2530  2025-01-24  607.969971  610.780029  606.799988  609.809998   34604700
# 2531  2025-01-27  599.369995  599.690002  594.640015  594.809998   70361100
# 2532  2025-01-28  604.520020  605.369995  597.250000  600.619995   44433300
# 2533  2025-01-29  601.809998  604.130005  599.219971  603.719971   37177400
# ...

# %%
cleaning.stat(spy)
# Out:
# Price                           Date        Close         High          Low  \
# count                           2535  2535.000000  2535.000000  2535.000000
# mean   2020-01-14 14:32:31.242603776   316.067402   317.725660   314.157889
# min              2015-01-02 00:00:00   156.800842   157.864136   154.676898
# 25%              2017-07-10 12:00:00   214.841957   215.702245   214.206908
# 50%              2020-01-15 00:00:00   277.117859   277.919519   276.073612
# 75%              2022-07-21 12:00:00   405.869217   409.134341   402.830874
# max              2025-01-30 00:00:00   609.750000   610.780029   606.799988
# std                              NaN   117.926910   118.486410   117.269903
#
# Price         Open        Volume
# count  2535.000000  2.535000e+03
# mean    316.021385  8.714655e+07
# min     156.354943  2.027000e+07
# 25%     214.972485  5.862005e+07
# 50%     277.230781  7.642870e+07
# 75%     406.100271  1.018866e+08
# max     609.809998  5.072443e+08
# ...

# %%
cleaning.Inspect(spy)
# Out:
# {'data_types': Price
#  Date      datetime64[ns]
#  Close            float64
#  High             float64
#  Low              float64
#  Open             float64
#  Volume             int64
#  dtype: object,
#  'missing_values': Price
#  Date      0
#  Close     0
#  High      0
#  Low       0
#  Open      0
#  Volume    0
#  dtype: int64,
#  'duplicate_rows': 0}

# %%
cleaning.detect_outliers_with_boxplot(spy,'Close')

# %%
analysis.closing(spy,'SPY')

# %%
analysis.precentage_change(spy)
# Out:
# /Users/amantebeje/Desktop/projects/gmf-investments-portfolio-forecasting-/scripts/eda.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
analysis.rolling_avg(spy)

# %%
analysis.outliers(spy)
# Out:
# Days with Unusually High or Low Returns:
# Price            Close        High         Low        Open     Volume  \
# Date
# 2015-08-24  160.697769  167.464880  154.676898  158.993275  507244300
# 2015-08-26  164.903946  165.183778  159.739558  162.885679  339257000
# 2016-06-24  176.086365  182.679640  175.635835  176.424259  333444400
# 2018-02-05  235.672028  246.315811  235.118413  244.172775  294681800
# 2018-02-08  230.046539  239.458069  230.010814  239.315197  246449500
# 2018-12-26  223.997894  223.997894  212.697003  214.707876  218485400
# 2020-02-24  298.923553  309.251708  297.829525  299.591084  161088400
# 2020-02-27  275.828827  288.854915  275.828827  283.199450  284353500
# 2020-03-02  286.564819  286.629725  273.000988  276.477703  238703600
# 2020-03-04  290.060120  290.282649  281.224625  283.811310  176613400
# 2020-03-05  280.418091  285.990119  278.146653  282.754463  186366800
# 2020-03-09  254.245346  263.479498  253.522190  255.237348  309417300
# ...

# %%
analysis.var_sharpe(spy)
# Out:
# Value at Risk (VaR) at 95.0% confidence level: -1.67%
# Sharpe Ratio: 0.05

# %%
analysis.decompose(spy)
